# %% [markdown]
# <a href="https://colab.research.google.com/github/InsightfulSantosh/Maths-for-Machine-Learning/blob/main/Calculus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Session Flow**
#
# 👨🏻‍🎓 **Learning Objective:**
#
# * Introduction
# * Theme
# * Primary Goals
#
# 📚**Learning material**
#
# * Calculus
#
# * Differentitation
#
# * Integration
#
# * Activity 1
#
# * Maxima and Minima using derivatives
#
# * Activity 2
#
# * Partial Derivatives
#
# 📝 **Summary**
#
# * What did we learn?
# * Shortcomings & Challenges
# * Best Practices & Tips
#
# 🔗 **Enhance your Knowledge**
#
# * Mnemonic
# * Additional Resources
#
# 🔍 **Try it Yourself**
#
# * Activities
# * Social Engagement

# %% [markdown]
# # **👨🏻‍🎓 Learning Objective 👨🏻‍🎓**

# %% [markdown]
# ## **Introduction:**
#
# 📢 Attention Students! 🎓
#
# I am thrilled to announce that you are about to embark on an incredible journey into the fascinating world of advanced maths for data science! 🤓📊
#
# In this course, we'll be delving deep into the intricacies of calculus, one of the most fundamental branches of mathematics. 🧮 With calculus, we'll be able to study and analyze complex systems and predict their behavior, which is a vital skill for any data scientist.
#
# We'll cover topics such as derivatives, integrals, limits, and functions. 📈 You'll learn how to apply these concepts to solve real-world problems in data science, such as optimization and prediction. We'll explore how to use calculus to analyze data sets and extract insights, giving you a powerful set of tools for working with data. 💻
#
# But calculus isn't just for data science - it has many practical applications in fields like physics, engineering, and economics. Understanding calculus will give you a strong foundation for further study in these areas as well.
#
# So, gear up and sharpen your pencils! 📚 This is going to be an exciting and challenging journey that will push your understanding of maths to new heights. But with dedication and hard work, you'll come out the other side with a deep understanding of one of the most powerful tools in the data scientist's toolkit. 🌟
#
# ##**Theme**
#
#  Advanced mathematics plays a crucial role in descriptive statistics because it provides the analytical tools and techniques needed to extract meaningful insights from complex datasets.📊📈 Descriptive statistics involve summarizing, organizing, and presenting data in a way that facilitates a deeper understanding of its underlying patterns and characteristics. 🔍 Advanced mathematical concepts, such as calculus, linear algebra, and probability theory, enable statisticians to develop sophisticated methods for measuring central tendencies, dispersion, and relationships between variables. 📊🧪 These advanced tools empower analysts to handle intricate data structures, model intricate distributions, and apply regression analysis to uncover significant trends. 🔄 Ultimately, the integration of advanced mathematics with descriptive statistics enhances the precision, accuracy, and depth of interpretation, enabling professionals to make more informed decisions and draw reliable conclusions from diverse datasets. 📚🔍
#
# ##**Primary goals**
#
# 1. Understanding the fundamental concepts of calculus, including derivatives, integrals, limits, and functions.🧮
# 2. Learning how to apply calculus to solve real-world problems in data science, such as optimization and prediction.📈
# 3. Developing problem-solving skills and a mathematical mindset to approach complex data science challenges.🤔
# 4. Understanding the use of partial derivatives to analyze multivariable functions and optimize solutions in various scenarios.
# 5. Learning about maxima and minima points using derivatives and their significance in finding extreme values in functions.
# 6. Enhancing analytical and critical thinking abilities to effectively interpret and apply advanced mathematical techniques in data science.🧠
#
# Happy learning! 🚀🎓

# %% [markdown]
# # **📖 Learning Material 📖**

# %% [markdown]
# ## **Calculus**

# %% [markdown]
# ### **Introduction:**

# %% [markdown]
# Calculus is a branch of mathematics that deals with the study of rates of change and how things change over time. It is widely used in various fields such as science, engineering, economics, and finance. In advanced maths for data science, calculus is an essential topic as it provides the foundation for many statistical and machine learning models.
#
# Here are some important topics to cover in the introduction to calculus:
#
# **1️⃣ Functions:**
#
# A function is a rule that assigns to each input value exactly one output value. It is represented by a graph, an equation, or a table. Some examples of functions are linear, quadratic, exponential, and trigonometric functions.
#
# **2️⃣ Limits:**
#
# A limit is the value that a function approaches as the input approaches a certain value. It is denoted by the symbol "lim" and is used to describe the behavior of a function near a specific point. The concept of limits is crucial in calculus as it forms the basis for derivatives and integrals.
#
# **3️⃣ Continuity:**
#
# A function is said to be continuous if its graph can be drawn without lifting the pen from the paper. A function is continuous at a point if it has a limit at that point and the limit is equal to the function value. Continuity is an essential concept in calculus as it helps in determining the behavior of a function near a particular point.
#
# **4️⃣ Derivatives:**
#
# A derivative is the rate at which a function changes with respect to its input. It measures the slope of the tangent line at a particular point on the graph of the function. The derivative is denoted by the symbol "dy/dx" or "f'(x)" and is used to solve optimization problems and to analyze the behavior of a function.

# %% [markdown]
# ### **Differentiation**

# %% [markdown]
# **🔢 What is Differentiation?**
#
# Differentiation is a method of finding the rate at which a function changes over a certain period of time. It is an important concept in calculus and is used to determine the maximum and minimum values of a function.
#
# **📝 Notation:**
#
# The derivative of a function f(x) with respect to x is denoted by f'(x) or dy/dx.
#
# **🧮 Formulas:**
#
#
# **1. Power Rule:**  **$\frac{d}{dx}x^n = nx^{n-1}$**
#
#
# **2. Product Rule:**  $\frac{d}{dx}(f(x)g(x)) = f'(x)g(x) + f(x)g'(x)$
#
# **3. Quotient Rule:** $\frac{d}{dx}\left(\frac{f(x)}{g(x)}\right) = \frac{f'(x)g(x) - f(x)g'(x)}{(g(x))^2}$
#
# **4. Chain Rule:** $\frac{d}{dx}f(g(x)) = f'(g(x))g'(x)$

# %% [markdown]
# **📈 Application:**
#
# Differentiation is used in many real-world applications, such as in finance to determine the maximum return on investment or in physics to determine the velocity and acceleration of an object.
#
# Overall, differentiation is a crucial concept in advanced maths for Data Science, and it is important to have a solid understanding of the formulas and their applications.

# %% [markdown]
# ***Example:***
#
# **Find the derivative of the function $f(x) = x^2 + 2x + 1$.**
#
# **Solution:**
#
# $f(x) = x^2 + 2x + 1$
#
# $f'(x) = 2x + 2$ (using power rule)
#
# **Therefore, the derivative of $f(x) = x^2 + 2x + 1$ is $f'(x) = 2x + 2$.**

# %% [markdown]
# ### **Integration**

# %% [markdown]
# 🧮 Integration is the inverse process of differentiation. It involves finding the function whose derivative is a given function. The symbol used to represent integration is the integral sign (∫), and the function to be integrated is placed after the integral sign. The limits of integration are also specified, which determine the range of values over which the integration is to be performed.
#
# 🔍 There are different techniques for integration, including:

# %% [markdown]
# ###🔄 Integration by Substitution:
#
# In this technique, we substitute a new variable for the original variable in the integral, which transforms the integral into a simpler form.
#
# **Example:** Evaluate the integral $\int 2x \cdot (x^2 + 1)^3 \, dx$.
#
# **Solution:**
# Let's use the substitution method to simplify the integral.
#
# Choose a substitution:  Let $$u = x^2 + 1$$.
#
# Differentiate  $u$ with respect to $x$: $$\frac{du}{dx} = 2x$$.
#
# Solve for $dx$:
#
# $$dx = \frac{du}{2x}$$.
#
# Now, substitute the expressions for $u$ and $dx$ into the integral:
#
#
# $$
# \int 2x \cdot (x^2 + 1)^3 \, dx = \int u^3 \cdot \frac{1}{2} \, du.
# $$
#
# Integrate with respect to $u$:
#
# $$
# \int u^3 \cdot \frac{1}{2} \, du = \frac{1}{2} \cdot \frac{u^4}{4} + C,
# = \frac{u^4}{8} + C.
# $$
#
# Substitute back for $u$:
#
# $$u = x^2 + 1$$,
# $$u^4 = (x^2 + 1)^4$$.
#
# So, the final result is:
#
# $$
# \int 2x \cdot (x^2 + 1)^3 \, dx = \frac{(x^2 + 1)^4}{8} + C,
# $$
#
# where $C$ is the constant of integration.
#
# This is an example of integration by substitution, where we chose a substitution to simplify the integral and then solved for the new variable to find the antiderivative.

# %% [markdown]
# ## **🤝 Integration by parts:**
#
# In this technique, we choose two parts of the integral and apply a formula to transform the integral into a simpler form.
#
# Integration by parts formula:
#
# $$\int u \, dv = uv - \int v \, du.$$
#
# **Example:**  Evaluate the integral:  $\int x \cdot e^x \, dx$.
#
# **Solution:**
# Integration by parts involves choosing two functions to differentiate and integrate.
#
#
# Let's choose $u = x$  and  $dv = e^x \, dx$.

# %% [markdown]
# ![Screenshot 2024-05-21 at 4.41.01 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## **🧩 Partial fraction decomposition:**
#
# This technique is used for integrating rational functions, where the function is expressed as a sum of simpler fractions.
#
# **Example:**
# Decompose the rational function $\frac{3x + 1}{x^2 + 2x}$ into partial fractions.
#
# **Solution:**
# To decompose the rational function, we want to express it as a sum of simpler fractions. First, we factor the denominator:
#
# $$x^2 + 2x = x(x + 2).$$
#
# Now, we want to express the given rational function as a sum of two partial fractions:
#
# $$\frac{3x + 1}{x^2 + 2x} = \frac{A}{x} + \frac{B}{x + 2}.$$
#
# Where $A$ and $B$ are constants that we need to find.
#
# To solve for $A$ and $B$, we'll find a common denominator on the right side:
#
# $$\frac{3x + 1}{x^2 + 2x} = \frac{A(x + 2)}{x(x + 2)} + \frac{Bx}{x(x + 2)}.$$
#
# Now, we'll combine the fractions:
#
# $$\frac{3x + 1}{x^2 + 2x} = \frac{A(x + 2) + Bx}{x(x + 2)}.$$
#
# We want the numerators to be the same, so we'll set up an equation:
#
# $$3x + 1 = A(x + 2) + Bx.$$
#
# Now, let's solve for $A$ and $B$:
#
# $$3x + 1 = Ax + 2A + Bx.$$
#
# Equating coefficients of $x$ terms:
# $$3 = A + B,$$
# $$1 = 2A.$$
#
# From the second equation, we find $A = \frac{1}{2}$.
#
# Substitute $A$ back into the first equation to find $B$:
# $$3 = \frac{1}{2} + B,$$
# $$B = 3 - \frac{1}{2},$$
# $$B = \frac{5}{2}.$$
#
# So, we have the partial fraction decomposition:
# $$\frac{3x + 1}{x^2 + 2x} = \frac{1}{2x} + \frac{5}{2(x + 2)}.$$
#
# This is the partial fraction decomposition of the given rational function.

# %% [markdown]
# ## **📐 Trigonometric substitution:**
# This technique is used for integrating expressions that involve trigonometric functions.![Screenshot 2024-05-21 at 4.21.25 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-05-21 at 4.21.41 PM.png](data:image/png;base64,...)

# %% [markdown]
# 🌐 Integration is used in many areas of mathematics and science, including physics, engineering, and economics. It has important applications in finding areas and volumes of complex shapes, computing work done by a force, and determining the probability of an event in statistics.

# %% [markdown]
# **Practice Problem**
#
# Q.
# $\int \frac{x}{x^2+1}dx$
#
# Answer. Let $u=x^2+1$, then $du/dx=2x$, which implies $dx=du/(2x)$.
#
# *Substituting these values in the integral, we get:*
#
#
# \begin{align*}
# \int \frac{x}{x^2+1}dx &= \frac{1}{2} \int \frac{1}{u}du\ &=\frac{1}{2} \ln|u| + C\
# &=\frac{1}{2} \ln|x^2+1| + C
# \end{align*}
#
#
# where $C$ is the constant of integration.

# %% [markdown]
# ##**Activity1: True or False**
#
# * True/False 1: Differentiation is the process of finding the slope of a curve at a specific point.
#
#
# * True/False 2: Integration is the process of finding the area under a curve.
#
#
# * True/False 3: The derivative of a constant function is not zero.
#
#
# * True/False 4: The integral of a constant function is always the value of the constant divided by the variable of integration.

# %% [markdown]
# ### **Answer**

# %% [markdown]
# Answer 1: True
#
# Answer 2: True
#
# Answer 3: False
#
# Answer 4: False

# %% [markdown]
# ### **Chain Rule**

# %% [markdown]
# **🔗 Chain Rule:**
#
# The chain rule is a formula for computing the derivative of the composition of two or more functions. In other words, it tells us how to take the derivative of a function that is formed by nesting one function inside another.
#
# **📝 Formula:**
#
# Let $f$ and $g$ be functions, and let $y = f(g(x))$ be their composite function. Then the derivative of $y$ with respect to $x$ is given by:
#
# If y = f(g(x)), then

# %% [markdown]
# $\dfrac{dy}{dx} = \dfrac{dy}{du} \cdot \dfrac{du}{dx} = f'(g(x)) \cdot g'(x)$
#
# $\dfrac{dx}{dy} = \dfrac{1}{\dfrac{dy}{dx}} = \dfrac{1}{f'(g(x)) \cdot g'(x)} = \dfrac{1}{\dfrac{dy}{du} \cdot \dfrac{du}{dx}}$

# %% [markdown]
# In other words, to find the derivative of a composite function, we need to take the derivative of the outer function with respect to the inner function, multiplied by the derivative of the inner function with respect to the variable we are differentiating with respect to.

# %% [markdown]
# **💡 Key Points:**
#
# 1. The chain rule is used to compute the derivative of composite functions.
#
# 2. The formula for the chain rule involves taking the derivative of the outer function evaluated at the inner function, multiplied by the derivative of the inner function.
#
# 3. The chain rule is an important tool in calculus and is used frequently in many areas of math and science.

# %% [markdown]
# ***Example:***

# %% [markdown]
# Let's say we have the function $f(x) = (x^2 + 3x)^4$, and we want to find the derivative of $f$ with respect to $x$. Using the chain rule, we can break down the problem into two smaller problems:
#
# First, we define $g(x) = x^2 + 3x$, and $h(u) = u^4$.
#
# Then we can write $f(x) = h(g(x))$,
#
# which means that $f$ is the composition of $g$ and $h$.
#
# Now we can apply the chain rule to find $f'(x)$:
#
#
# $$\frac{df}{dx} = \frac{dh}{du} \cdot \frac{dg}{dx} = \frac{4u^3.du}{du} \cdot \frac{(2x + 3)dx}{dx} =4u^3⋅(2x+3)$$.
#
#
# But we're not done yet! We need to substitute $u = g(x) = x^2 + 3x$ back into this expression to get our final answer:
#
# $$\frac{df}{dx} = 4(x^2 + 3x)^3 \cdot (2x + 3)$$.
#
#
# ***So the derivative of $f(x) = (x^2 + 3x)^4$ is $$f'(x) = 4(x^2 + 3x)^3 \cdot (2x + 3)$$.***

# %% [markdown]
# ### **Maxima and Minima using derivatives**

# %% [markdown]
# 📈 Maxima and minima are critical points in a function that represent its highest and lowest values, respectively. In calculus, we use derivatives to find these points.
#
# 🔍 To find the maxima and minima of a function, we first take the first derivative of the function and set it equal to zero. We then solve for the values of x that make the derivative zero. These values are known as critical points.
#
# 📝 We then analyze the second derivative of the function at these critical points. If the second derivative is positive at a critical point, then the point is a local minimum. If the second derivative is negative, then the point is a local maximum. If the second derivative is zero, then further analysis is required.

# %% [markdown]
# ***Example:***

# %% [markdown]
# Find the maximum and minimum values of the function $f(x) = 2x^3 - 9x^2 + 12x + 4$ on the interval $[0, 4]$.

# %% [markdown]
# **Solution:**
#
# To find the critical points of $f(x)$, we take the first derivative and set it equal to zero:
#
# $f'(x) = 6x^2 - 18x + 12 = 0$
#
# Solving for $x$, we get:
#
# $x = 1$ or $x = 2$
#
# Now, we need to check the values of $f(x)$ at the critical points and at the endpoints of the interval $[0,4]$:
#
# $f(0) = 4$
#
# $f(1) = 9$
#
# $f(2) = 8$
#
# $f(4) = 68$
#
# Therefore, the minimum value of $f(x)$ is 4, which occurs at $x = 0$, and the maximum value of $f(x)$ is 68, which occurs at $x = 4$.

# %% [markdown]
# *To summarize:*
#
# 1. To find the critical points of a function, we take the first derivative and set it equal to zero.
#
# 2. To determine if a critical point is a maximum, minimum, or neither, we use the second derivative test. If $f''(x) > 0$, the critical point is a minimum; if $f''(x) < 0$, the critical point is a maximum; and if $f''(x) = 0$, the test is inconclusive.
#
# 3. To find the maximum and minimum values of a function on a closed interval, we evaluate the function at the critical points and at the endpoints of the interval. The largest of these values is the maximum value, and the smallest is the minimum value.

# %% [markdown]
# ##**Activity: Guess the word**
#
# * Riddle 1:
#
#   On a curve I dwell, where heights and depths play,
# Seeking extreme points, I guide the way.
# With calculus in hand, I climb and dive,
# To find where functions peak and thrive.
#
#   What am I?
#
# * Riddle 2:
#
#   In functions woven, a tale to tell,
# A chain of changes, where they dwell.
# With a rule that links them, I swiftly derive,
# From outside to inside, my steps I contrive.
#
#   What am I?

# %% [markdown]
# ###**Answer**

# %% [markdown]
# Answer 1: A seeker of maxima and minima using derivatives
#
# Answer 2: The chain rule in integration

# %% [markdown]
# ### **Partial Derivatives**

# %% [markdown]
# **Definition:**
#
# A partial derivative of a multivariable function is the derivative with respect to one of its variables, keeping all other variables constant. For example, if we have a function $f(x, y)$, the partial derivative of $f$ with respect to $x$ is denoted as $\frac{\partial f}{\partial x}$ and is defined as the rate of change of $f$ as $x$ changes, with $y$ held constant.
#
# **Notation:**
#
# The partial derivative of a function $f(x,y)$ with respect to $x$ is denoted by $\frac{\partial f}{\partial x}$. The symbol $\partial$ is used to indicate a partial derivative, and it is pronounced "dee" or "del". To denote the partial derivative of $f$ with respect to $y$, we write $\frac{\partial f}{\partial y}$.
#
# **Interpretation:**
#
# The partial derivative of a function gives us the rate at which the function changes as one of its input variables changes, while holding all other input variables constant. It tells us how much the output of the function changes when we change only one of the input variables.
#
# **Rules:**
#
# Just like ordinary derivatives, partial derivatives satisfy many of the same rules. Here are a few of the most important ones:
#
# **1. The sum rule:** $\frac{\partial (f+g)}{\partial x} = \frac{\partial f}{\partial x} + \frac{\partial g}{\partial x}$
#
# **2. The product rule:** $\frac{\partial (fg)}{\partial x} = f \frac{\partial g}{\partial x} + g \frac{\partial f}{\partial x}$
#
# **3. The chain rule:** $\frac{\partial f(u,v)}{\partial x} = \frac{\partial f}{\partial u} \frac{\partial u}{\partial x} + \frac{\partial f}{\partial v} \frac{\partial v}{\partial x}$
#
# **Application:**
#
# Partial derivatives are used in many areas of mathematics and science, including optimization, physics, economics, and engineering. For example, in optimization problems, we may need to find the maximum or minimum value of a function of several variables. To do this, we can take partial derivatives of the function with respect to each variable, set them equal to zero, and solve for the variables.

# %% [markdown]
# ***Example:***

# %% [markdown]
# **Suppose we have the function f(x,y) = $x^2y + y^3$, and we want to find the partial derivatives with respect to x and y at the point (1,2).**
#
# The partial derivative with respect to x can be found by treating y as a constant and taking the derivative of the function with respect to x:
#
# $\frac{\partial f}{\partial x} = 2xy$
#
# At the point (1,2), this gives us:
#
# $\frac{\partial f}{\partial x}(1,2) = 2(1)(2) = 4$
#
# The partial derivative with respect to y can be found by treating x as a constant and taking the derivative of the function with respect to y:
#
# $\frac{\partial f}{\partial y} = x^2 + 3y^2$
#
# At the point (1,2), this gives us:
#
# $\frac{\partial f}{\partial y}(1,2) = (1)^2 + 3(2)^2 = 13$
#
# *Therefore, the partial derivatives of f(x,y) with respect to x and y at the point (1,2) are 4 and 13, respectively.*

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ###📚 **What did you learn?** 🤔
#
# 👉 You learned about the fundamental concepts of calculus, including derivatives, integrals, limits, and functions.
#
# 👉 You learned how to apply calculus to solve real-world problems in data science, such as optimization and prediction.
#
# 👉 You learned how to use calculus to analyze and extract insights from data sets.
#
# 👉 You gained practical knowledge of calculus applications in fields such as physics, engineering, and economics.
#
# 👉 You sharpened your problem-solving skills and developed a mathematical mindset.
#
#
# 🎓 Congratulations on completing this course! You've developed a strong foundation in advanced maths for data science, giving you a competitive edge in your studies and career. Keep exploring and applying your new knowledge, and remember to stay curious and keep learning! 🤗

# %% [markdown]
# ###🤔 **Shortcomings**
#
# 👎 Calculus can be a difficult subject to master, especially if you don't have a strong foundation in algebra and trigonometry. Don't get discouraged if you don't understand everything at first. It takes time and practice to develop a deep understanding of the subject. 📚
#
# 👎 Calculus can also be quite abstract, which can make it challenging to apply to real-world problems. Keep practicing and exploring different applications to develop your intuition and problem-solving skills. 🤹‍♀️
#
# 👎 It's important to stay organized and keep detailed notes when working on calculus problems, as small mistakes can have a big impact on your results. Make sure to double-check your work and ask for feedback when you're not sure. 📝
#
# 👎 Finally, calculus is just one tool in a data scientist's toolbox. It's important to develop a well-rounded skill set that includes programming, statistics, and other subjects to be successful in the field. 🧰
#
# 🎓 By keeping these shortcomings in mind and working to overcome them, you'll be well on your way to becoming a skilled and successful data scientist. Remember, every challenge is an opportunity to learn and grow! 🌱

# %% [markdown]
# ###👩‍🏫 **Best Practices and Tips**
#
# 👉 Practice, practice, practice! The more problems you solve, the better you'll get at applying calculus concepts to real-world scenarios. 🏋️‍♀️
#
# 👉 Build a strong foundation in algebra and trigonometry, as these subjects are closely related to calculus. 🧮
#
# 👉 Stay organized and keep detailed notes, especially when working on complex problems. This will help you keep track of your progress and identify areas for improvement. 📝
#
# 👉 Don't be afraid to ask for help if you get stuck. Reach out to your teachers, classmates, or online communities for support. 💬
#
# 👉 Keep an open mind and stay curious. Explore different applications of calculus in data science and beyond. You never know where it might lead you! 🤔
#
# 🎓 By following these best practices and tips, you'll be well on your way to mastering advanced maths for data science. Good luck and happy studying! 🚀

# %% [markdown]
# # **➕ Additional Reading ➕**

# %% [markdown]
# ### **Mnemonic:**
#
# 📚 Once upon a time, there were three data scientists 🧑‍💻👩‍💻👨‍💻 who were given a challenging task to complete. They had to analyze a large dataset and find patterns that could help their company optimize their marketing strategy.
#
# 📈 The data scientists knew they had to use calculus to solve this problem, so they got to work. They used derivatives to find the slope of the data, integrals to find the total area under the curve, and limits to determine the boundaries of the data.
#
# 🧐 As they analyzed the data, they discovered a clear pattern: their target audience was much more likely to engage with social media posts that included pictures of cats 🐱. Armed with this knowledge, the data scientists were able to adjust their marketing strategy and increase engagement by over 50% 🚀.
#
# 🎉 The team was thrilled with their success and celebrated with a big bowl of cat-shaped cookies 🍪. They knew that their knowledge of calculus had helped them solve a complex problem and achieve great results.
#
# 🤓 So, remember, when you're working on data science problems, don't forget to apply the concepts you learned in our advanced maths course! You never know when they might help you discover the next big breakthrough. 🌟

# %% [markdown]
# ###📚 **If you're interested in delving deeper into the subject of advanced maths for data science, here are some additional reading materials that you may find helpful:**
#
# 📖 "Calculus for Data Science: A Guide to Machine Learning" by Dr. Andrew Catlin. This book provides a practical introduction to calculus concepts and their applications in machine learning.
#
# 📖 "Mathematics for Machine Learning" by Marc Peter Deisenroth, A. Aldo Faisal, and Cheng Soon Ong. This book covers the mathematical foundations of machine learning, including calculus, linear algebra, and probability theory.
#
# 📖 "Calculus: Early Transcendentals" by James Stewart. This classic textbook provides a comprehensive introduction to calculus concepts and includes many real-world applications.
#
# 📖 "Deep Learning" by Ian Goodfellow, Yoshua Bengio, and Aaron Courville. This book covers the mathematical foundations of deep learning, including calculus, linear algebra, and probability theory.
#
# 📖 "The Elements of Statistical Learning" by Trevor Hastie, Robert Tibshirani, and Jerome Friedman. This book covers the mathematical foundations of statistical learning, including calculus, linear algebra, and probability theory.
#
# ### **Additional Resources**
#
# * http://educatia21.reviste.ubbcluj.ro/data/uploads/article/2021/ed21-no21-art11.pdf
#
# * https://www.ilkogretim-online.org/fulltext/218-1652865446.pdf
#
# 👨‍🏫 These resources will give you a more in-depth understanding of the subject and help you apply calculus concepts to real-world problems. Happy reading! 📚

# %% [markdown]
# # **Try it yourself📃📟**
#
# Are you ready to put your coding skills to the test and gain practical knowledge? We have some exciting coding questions waiting for you to solve! 🚀
#
# Your task is to attempt the coding questions associated with this lesson. These challenges have been thoughtfully designed to reinforce your understanding of the concepts covered in the course. You can find them in your dashboard under this lesson.

# %% [markdown]
# ## **Task 1**

# %% [markdown]
# ### **🎓 Activity 1:**

# %% [markdown]
# Find the derivative of the function $f(x) = x^3 - 2x^2 + 5x - 3$

# %% [markdown]
# ### **🎓 Activity 2:**

# %% [markdown]
# Find the indefinite integral of $f(x) = 3x^2 - 5x + 7$ using integration by substitution.

# %% [markdown]
# ### **🎓 Activity 3:**

# %% [markdown]
# #### 🔗🧩💻 Integration
#
# #### Evaluating Integrals
#
# 1. Find the integral of the function:  $\int_{}^{} x^{2}dx$
#
#
#
# 2. $\int (x^{2}-1)(4+3x) \, dx$

# %% [markdown]
# ### **🎓 Activity 4:**

# %% [markdown]
# A company is planning to produce a rectangular box with a fixed volume of 12 cubic meters. The material cost of the top and bottom is $1/m^2$, and the material cost of the sides is $2/m^2$. What dimensions of the box minimize the material cost? 📦💰

# %% [markdown]
# ### **Activity 5: 🧮 Multivariable Calculus**

# %% [markdown]
# #### 📐Partial Derivatives
#
# In this activity, we will calculate partial derivatives using Python and Sympy.
#
# 1. Find the partial derivatives of `f(x, y) = x^2 + xy + y^2` with respect to `x` and `y`.
#
# 2. Find the partial derivatives of `g(x, y, z) = x^2yz + 3xy + z^2` with respect to `x`, `y`, and `z`.
#
# #### 📊Double Integrals
#
# In this activity, we will evaluate double integrals using Python and Sympy.
#
# 1. Calculate the double integral of `f(x, y) = x + y` over the region `0 <= x <= 1` and `0 <= y <= 2`.
#
# 2. Calculate the double integral of `g(x, y) = x^2y` over the region `0 <= x <= 1` and `0 <= y <= x`.

# %% [markdown]
# ![](data:image/jpeg;base64,...)
